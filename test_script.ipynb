# %%
# %matplotlib notebook
from play_ import run
from learnfromhuman import LearnFromHuman
lfh = run()

# %%
print(lfh.step)
# Out:
# 0

# %%
lfh.chooseIdx()
# Out:
# <img src="data:image/png;base64,..." width="750">

# %%
lfh.updateLearner()

# %%
import numpy as np 
data1=np.load('data.npy', allow_pickle=True)
lfh.saveData()

# %%
print(data1)
# Out:
# {'batches': [[array([14, 16,  9, 19, 17, 22,  4,  5, 10,  1]), array([3, 3, 1, 0, 3, 1, 1, 1, 1, 2])]], 'ws': [array([[ 1.5009,  0.2632, -0.4069, -1.568 , -0.5646,  1.7237,  0.1647,
#          0.2528, -1.709 , -1.5749, -0.9999,  0.5746,  1.1131,  0.4582,
#          0.4122, -1.0692, -1.9865,  1.2664,  0.5229,  0.5126, -1.4015,
#         -0.1149,  0.7941, -0.6044, -0.4909]])], 'learned_rewards': [array([[ 1.5735,  0.2119, -0.4414, -1.6028, -0.6771,  1.6976,  0.1054,
#          0.2619, -1.7407, -1.5485, -0.9304,  0.5296,  1.9653,  0.4501,
#          0.6918, -1.0387, -1.9424,  1.3351, -0.9389,  0.3769, -1.4014,
#         -0.1426,  1.4309, -0.6427, -0.5137]])], 'policy': [array([[ 2.8808,  2.9119,  2.8808,  1.7631],
#        [ 1.4969,  1.4688,  2.6145,  0.5074],
#        [ 0.2311,  1.2467,  1.2206, -1.1237],
#        [-1.4468, -1.0251, -0.092 , -1.1383],
#        [-1.2231, -1.1097, -1.5316, -1.2231],
#        [ 2.7168,  0.7217,  2.7479,  1.5711],
#        [ 1.6029,  1.8362,  2.7517,  1.6291],
#        [ 0.361 ,  2.585 ,  1.3224, -0.5721],
#        [-1.186 ,  1.3235,  1.1845, -0.7641],
#        [-1.0293,  0.9396, -0.9161, -0.9159],
#        [ 2.5277, -0.4811,  0.5015,  1.6121],
#        [ 1.3469, -0.3582,  0.4975,  2.6095],
#        [ 1.6184,  2.4443,  1.8256,  1.7574],
#        [-0.5728,  0.3911,  2.5844,  1.2829],
#        [-0.6138,  0.9103,  1.4737,  1.2416],
#        [ 0.0886, -1.0107, -0.894 , -0.7671],
#        [ 1.6203,  0.9072, -0.4729,  2.2391],
#        [ 2.671 ,  2.2483, -0.2967,  0.4777],
#        [ 1.6381,  0.6594,  2.3251,  1.0748],
#        [ 1.2083,  0.0655,  0.3165,  0.877 ],
#        [-0.8815, -0.9982, -0.9982,  0.4987],
#        [-0.5182,  0.7351, -0.7618,  2.0268],
#        [ 2.3709,  2.3307,  1.039 ,  0.7052],
#        [ 0.3541,  0.4992,  2.1247,  0.1031],
#        [ 0.7961, -0.0154,  0.3807, -0.0154]])], 'selected_indices': [4]}
